# %%
import matplotlib.pyplot as plt
x=["part 1","part 2","part 3","part 4","part 5"]
y=[50,40,70,60,80]
plt.bar(x,y,color="pink")
plt.xlabel("Parts of Harry Potter")
plt.ylabel("Popularity",fontsize=10)
plt.title("Popularity of Different Parts of Harry Potter")
plt.show()

# %%
import matplotlib.pyplot as plt
x=["part 1","part 2","part 3","part 4","part 5"]
y=[50,40,70,60,80]
color=["Green","yellow","Red","Pink"]
plt.bar(x,y,color=color)
plt.xlabel("Parts of Harry Potter")
plt.ylabel("Popularity",fontsize=10)
plt.title("Popularity of Different Parts of Harry Potter")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/expense3.xlsx")
print(df)
plt.bar(df["Payment Mode"],df["Amount"])
plt.show()
a=df.groupby("Payment Mode")["Amount"].sum()
print(a)
plt.bar(a.index,a.values)
plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04        Food              Zomato     257         Cash
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50         Cash
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120         Cash
# ...

# %%
import matplotlib.pyplot as plt
x=[25,30,35,50,60]
y=[5,10,15,20,25]
y1=[10,20,30,40,50]
plt.plot(x,y,marker="*",color="red",label="week1")
plt.plot(x,y1,marker="*",color="blue",label="week2")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/expense3.xlsx")
print(df)
plt.plot(df["Date"],df["Amount"],color="green")
plt.show()
a=df.groupby("Category")["Amount"].sum()
print(a)
plt.plot(a.index,a.values)
plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04        Food              Zomato     257         Cash
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50         Cash
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120         Cash
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.randint(10,100,50)
y=np.random.randint(10,100,50)
color=np.random.randint(10,100,50)
plt.scatter(x,y,marker="*",cmap="viridis",c=color)
plt.colorbar()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/ESD.xlsx")
print(df)
plt.scatter(df["Age"],df["EEID"])
plt.show()
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
import matplotlib.pyplot as plt
brands=["samsung","nokia","lava","vivo","oppo"]
x=[10,30,25,5,16]
c=["red","green","yellow","pink","blue"]
ex=[0,0,0,0,0.1]
plt.pie(x,labels=brands,colors=c,explode=ex,shadow=True,autopct="%.2f",startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/expense3.xlsx")
print(df)
plt.pie(df["Amount"])
plt.show()
a=df.groupby("Payment Mode")["Amount"].sum()
print(a)
plt.pie(a.values,labels=a.index)
plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04        Food              Zomato     257         Cash
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50         Cash
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120         Cash
# ...

# %%
import matplotlib.pyplot as plt
a=[14,50,30,20,35,40,45,50,55,60,65,75,85,80,70]
b=[15,20,14,24,16,26,24,21,29,25,37,36]
plt.boxplot([a,b])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/expense3.xlsx")
plt.boxplot(df["Amount"])
plt.show()
print(df)
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04        Food              Zomato     257         Cash
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50         Cash
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120         Cash
# ...

# %%
import matplotlib.pyplot as plt
x=[4,6,7,14,45,37,74,34,23,15,15,24,5,4,24,35,26,15]

plt.hist(x,bins=10,edgecolor="black",color="red")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/ESD.xlsx")
plt.hist(df["Age"],bins=20,edgecolor="black")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10.15,14,13,12,25,26,36,37,37,28,29]
plt.violinplot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50]
plt.stem(a,linefmt="--",markerfmt="D",bottom=10)
plt.show()

# %%
import matplotlib.pyplot as plot
days=[1,2,3,4,5,6,7]
NOP1=[20,10,30,23,24,25,15]
NOP2=[14,15,16,25,24,29,35]
NOP3=[23,14,26,27,38,29,28]
plt.stackplot(days,NOP1,NOP2,NOP3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=["day1","day2","day3","day4","day5"]
y=[5,10,15,20,25]
plt.step(x,y,where="post",marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel("C:/Users/lenovo/OneDrive/Documents/AI and ML/expense3.xlsx")
print(df)
a=df.groupby("Category").agg({"Amount":"sum"})
plt.step(a.index,a["Amount"])
plt.savefig("step.png")
plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04        Food              Zomato     257         Cash
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50         Cash
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120         Cash
# ...

# %%
#Legends
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y1=[13,24,35,46,57]
y2=[14,25,37,45,59]
plt.plot(x,y1,label="male")
plt.plot(x,y2,label=)
plt.show()
